# %%
import os
import numpy as np
import mne
import pandas as pd
import scipy.io 
import matplotlib as plt

# %%
sample_data_path = os.path.join(os.getcwd(), 'data','Concert_EEG.mat')
mat = scipy.io.loadmat(sample_data_path)

# %%
i = 0
for element in mat['EEG'][0][0]:
    print(element)
    print(element.shape)
    print('-------------------------------------------')
    i += 1
    
print(i)
# Out:
# ['AureliaMusic_20241118_162144']
# (1,)
# -------------------------------------------
# []
# (0,)
# -------------------------------------------
# []
# (0,)
# -------------------------------------------
# []
# (0,)
# -------------------------------------------
# []
# (0,)
# -------------------------------------------
# []
# (0,)
# -------------------------------------------
# []
# (0, 0)
# -------------------------------------------
# []
# (0,)
# -------------------------------------------
# [[129]]
# (1, 1)
# -------------------------------------------
# [[1]]
# (1, 1)
# -------------------------------------------
# [[1431155]]
# (1, 1)
# -------------------------------------------
# [[1000]]
# (1, 1)
# -------------------------------------------
# [[0]]
# (1, 1)
# -------------------------------------------
# [[1431.154]]
# (1, 1)
# -------------------------------------------
# [[      0       1       2 ... 1431152 1431153 1431154]]
# (1, 1431155)
# ...
